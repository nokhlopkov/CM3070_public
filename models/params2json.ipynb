# %%
import json
import os

#Vision Transformer
vit_v = {
    #model hyperparameters
    'image_size': 224, #256
    'num_channels': 3,
    'transformer_layers': 8,
    'patch_size': 32,
    'projection_dim': 256,
    'num_heads': 4,

    # learning hyperparameters
    'learning_rate': 1e-4,
    'weight_decay' : 1e-4,
    'mlp_head_units' : [2048, 1024],  # Size of the dense layers of the final classifier

    #training hyperparameters
    'num_epochs': 30,
    'validation_epochs': 10,
    'batch_size': 512,

    'seed': 1,
}

vit_vs = {
    #model hyperparameters
    'image_size': 224, #256
    'num_channels': 3,
    'encoder_layers': 8,
    'decoder_layers': 4,
    'patch_size': 32,
    'encoder_projection_dim': 512,
    'decoder_projection_dim': 256,
    'num_heads': 4,
    'mask_rate': 0.0, # 0.75 for SST

    # learning hyperparameters
    'learning_rate': 1e-4,
    'weight_decay' : 1e-4,
    'mlp_head_units' : [2048, 1024],  # Size of the dense layers of the final classifier

    #training hyperparameters
    'num_epochs': 10,
    'validation_epochs': 10,
    'batch_size': 512,

    'seed': 1,
}

vit_sherlock = {
    #model hyperparameters
    'image_size': 224, #256
    'num_channels': 3,
    'encoder_layers': 12,
    'decoder_layers': 4,
    'patch_size': 16,
    'encoder_projection_dim': 768,
    'decoder_projection_dim': 384,
    'num_heads': 6,
    'mask_rate': 0.0, # 0.75 for SST

    # learning hyperparameters
    'learning_rate': 1e-4,
    'weight_decay' : 1e-4,
    'mlp_head_units' : [2048, 1024],  # Size of the dense layers of the final classifier

    #training hyperparameters
    'num_epochs': 10,
    'validation_epochs': 0,
    'batch_size': 64,

    'seed': 1,
}

vit_b_16 = {
    #model hyperparameters
    'image_size': 224, #256
    'num_channels': 3,
    'transformer_layers': 12,
    'patch_size': 16,
    'projection_dim': 768,
    'num_heads': 12,

    # learning hyperparameters
    'learning_rate': 1e-4,
    'weight_decay' : 1e-4,
    'mlp_head_units' : [2048, 1024],  # Size of the dense layers of the final classifier

    #training hyperparameters
    'num_epochs': 30,
    'validation_epochs': 10,
    'batch_size': 64,

    'seed': 1,
}


#ResNet18
resnet18 = {
    # model hyperparameters
    'image_size': 224,  # ResNet18 usually takes 224x224 images
    'num_channels': 3,

    # learning hyperparameters
    'learning_rate': 1e-1,
    'weight_decay': 1e-5,

    # training hyperparameters
    'num_epochs': 30,
    'validation_epochs': 0,
    'batch_size': 256,

    'seed': 1,
}

#MobileNetV2
mobilenetv2 = {
    # model hyperparameters
    'image_size': 224,  # MobileNetV2 usually takes 224x224 images
    'num_channels': 3,

    # learning hyperparameters
    'learning_rate': 0.045,
    'weight_decay': 0.00004,

    # training hyperparameters
    'num_epochs': 100,
    'validation_epochs': 0,
    'batch_size': 32,

    'seed': 1,

}

with open('ViT-SHERLOCK-params.json', 'w') as f:
    json.dump(vit_sherlock, f)
    
# with open('ResNet18.json', 'w') as f:
#     json.dump(resnet18, f)

# with open('MobileNetV2.json', 'w') as f:
#     json.dump(mobilenetv2, f)
